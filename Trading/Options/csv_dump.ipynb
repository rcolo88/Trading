# %%
import pandas as pd

# %%
df = pd.read_csv('optimization_results/compiled/CallCalendarSpread_compiled_20250103_20251117_good_run.csv')

# %%
df2 = df.head(1)

# %%
df2.to_csv("past_working_results.csv")
